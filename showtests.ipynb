# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
parameter = 'cutoff'
genres = ['rap', 'rock', 'pop']
# genres = ['rap', 'rock', 'pop', 'rb', 'country']
xs, ys, zs = [], [], []
limits = [100, 1000]
for limit in limits:
    file_name = f'output/{limit}/{parameter}/{"_".join(genres)}.csv'
    df = pd.read_csv(file_name)
    xs.append(df[parameter])
    ys.append(df['accuracy'])
    zs.append(df['features'])

fig, (ax1, ax2) = plt.subplots(2, 1)
fig.suptitle(f'{parameter}')
ax1.set_title('accuracy')
ax2.set_title('features')
for i in range(len(xs)):
    ax1.plot(xs[i], ys[i])
    ax2.plot(xs[i], zs[i])
fig.legend(limits)

print(df)

plt.show()
# Out:
#     Unnamed: 0  cutoff  accuracy   f1score  features
# 0            0       0  0.710000  0.705564     22033
# 1            0       1  0.720000  0.717261     12610
# 2            0       2  0.703333  0.699143      9674
# 3            0       3  0.703333  0.698956      7999
# 4            0       4  0.700000  0.694195      6924
# 5            0       5  0.703333  0.697693      6099
# 6            0       6  0.713333  0.708763      5014
# 7            0       7  0.713333  0.708763      5014
# 8            0       8  0.713333  0.708085      4622
# 9            0       9  0.710000  0.705261      4276
# 10           0      10  0.706667  0.700801      4022
# 11           0      11  0.710000  0.704549      3806
# 12           0      12  0.706667  0.701876      3586
# 13           0      13  0.710000  0.705061      3220
# 14           0      14  0.710000  0.705061      3220
# 15           0      15  0.716667  0.711200      3076
# 16           0      16  0.713333  0.708085      2957
# 17           0      17  0.710000  0.704094      2853
# 18           0      18  0.720000  0.714032      2750
# 19           0      19  0.716667  0.711180      2665
# 20           0      20  0.716667  0.711260      2574
# 21           0      21  0.723333  0.718437      2483
# 22           0      22  0.723333  0.719121      2410
# 23           0      23  0.720000  0.714955      2345
# 24           0      24  0.713333  0.708036      2290
# 25           0      25  0.713333  0.707928      2223
# 26           0      26  0.710000  0.704772      2166
# 27           0      27  0.720000  0.715407      2062
# 28           0      28  0.720000  0.715407      2062
# 29           0      29  0.720000  0.715407      2006
# 30           0      30  0.720000  0.715407      1907
# 31           0      31  0.720000  0.715407      1907
# 32           0      32  0.726667  0.722948      1861
# 33           0      33  0.730000  0.726461      1816
# 34           0      34  0.730000  0.726663      1776
# 35           0      35  0.730000  0.727005      1725
# 36           0      36  0.733333  0.729394      1685
# 37           0      37  0.730000  0.725668      1660
# 38           0      38  0.730000  0.726834      1625
# 39           0      39  0.726667  0.722761      1593
# 40           0      40  0.730000  0.726464      1563
# 41           0      41  0.730000  0.726612      1531
# 42           0      42  0.730000  0.726464      1501
# 43           0      43  0.730000  0.726464      1473
# 44           0      44  0.730000  0.726464      1451
# 45           0      45  0.730000  0.726464      1426
# 46           0      46  0.730000  0.726464      1397
# 47           0      47  0.726667  0.723338      1377
# 48           0      48  0.726667  0.723338      1363
# 49           0      49  0.730000  0.727369      1333

# %%
parameter = 'n-gram'
genres = ['rap', 'rock', 'pop']
# genres = ['rap', 'rock', 'pop', 'rb', 'country']
xs, ys, zs = [], [], []
limits = [100, 1000]
for limit in limits:
    file_name = f'output/{limit}/{parameter}/{"_".join(genres)}.csv'
    df = pd.read_csv(file_name)
    xs.append(df[parameter])
    ys.append(df['accuracy'])
    zs.append(df['f1score'])

fig, (ax1, ax2) = plt.subplots(2, 1)
fig.suptitle(f'{parameter}')
ax1.set_title('accuracy')
ax2.set_title('f1score')
for i in range(len(xs)):
    ax1.plot(xs[i], ys[i])
    ax2.plot(xs[i], zs[i])
fig.legend(limits)

print(df)

plt.show()
# Out:
#    Unnamed: 0  n-gram  accuracy   f1score       time
# 0           0       1  0.710000  0.705564   2.152840
# 1           0       2  0.660000  0.636720  47.054945
# 2           0       3  0.543333  0.538191  89.686644
# 3           0       4  0.396667  0.346847  85.427690

# %%
parameter = 'n-gram-reduced'
genres = ['rap', 'rock', 'pop']
# genres = ['rap', 'rock', 'pop', 'rb', 'country']
xs, ys, zs = [], [], []
limits = [100, 1000]
for limit in limits:
    file_name = f'output/{limit}/{parameter}/{"_".join(genres)}.csv'
    df = pd.read_csv(file_name)
    xs.append(df[parameter])
    ys.append(df['accuracy'])
    zs.append(df['f1score'])

fig, (ax1, ax2) = plt.subplots(2, 1)
fig.suptitle(f'{parameter}')
ax1.set_title('accuracy')
ax2.set_title('f1score')
for i in range(len(xs)):
    ax1.plot(xs[i], ys[i])
    ax2.plot(xs[i], zs[i])
fig.legend(limits)

print(df)

plt.show()
# Out:
#    Unnamed: 0  n-gram-reduced  accuracy   f1score       time
# 0           0               1  0.706667  0.700801   0.346089
# 1           0               2  0.653333  0.630146  35.847122
# 2           0               3  0.550000  0.542721  74.488306
# 3           0               4  0.400000  0.357547  74.324726

# %%
parameter = 'n-gram-reduced-more'
genres = ['rap', 'rock', 'pop']
# genres = ['rap', 'rock', 'pop', 'rb', 'country']
xs, ys, zs = [], [], []
limits = [100, 1000]
for limit in limits:
    file_name = f'output/{limit}/{parameter}/{"_".join(genres)}.csv'
    df = pd.read_csv(file_name)
    xs.append(df[parameter])
    ys.append(df['accuracy'])
    zs.append(df['f1score'])

fig, (ax1, ax2) = plt.subplots(2, 1)
fig.suptitle(f'{parameter}')
ax1.set_title('accuracy')
ax2.set_title('f1score')
for i in range(len(xs)):
    ax1.plot(xs[i], ys[i])
    ax2.plot(xs[i], zs[i])
fig.legend(limits)

print(df)

plt.show()
# Out:
#    Unnamed: 0  n-gram-reduced-more  accuracy   f1score       time
# 0           0                    1  0.713333  0.707928   0.151245
# 1           0                    2  0.653333  0.635343  28.842108
# 2           0                    3  0.553333  0.543977  67.467010
# 3           0                    4  0.406667  0.369174  71.122553

# %%
parameter = 'stem'

xs, ys = [], []
limits = [100, 1000]
for limit in limits:
    file_name = f'output/{limit}/{parameter}/{"_".join(genres)}.csv'
    df = pd.read_csv(file_name)
    xs.append(list(df[parameter]))
    ys.append(list(df['accuracy']))

fig, axs = plt.subplots(1, len(limits))
fig.suptitle(f'{parameter}')
for i, ax in enumerate(axs):
    ax.set_title(f'{limits[i]}')
    ax.bar(xs[i], ys[i])
plt.show()

# %%
xs, ys, zs = [], [], []
limits = [100, 1000]
for limit in limits:
    file_name = f'output/{limit}/{parameter}/{"_".join(genres)}.csv'
    df = pd.read_csv(file_name)
    xs.append(list(df[parameter]))
    ys.append(list(df['accuracy']))
    zs.append(list(df['time']))

fig, axs = plt.subplots(1, len(limits))
fig.suptitle(f'{parameter}')
for i, ax in enumerate(axs):
    ax.set_title(f'{limits[i]}')
    ax.bar(xs[i], ys[i])
plt.show()

fig, axs = plt.subplots(1, len(limits))
fig.suptitle(f'time')
for i, ax in enumerate(axs):
    ax.set_title(f'{limits[i]}')
    ax.bar(xs[i], zs[i])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File e:\OneDrive\Study\CS Master\Natural Language Processing\Project\nlpprojectvenv\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'time'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 8
#       6     xs.append(list(df[parameter]))
#       7     ys.append(list(df['accuracy']))
# ----> 8     zs.append(list(df['time']))
#      10 fig, axs = plt.subplots(1, len(limits))
#      11 fig.suptitle(f'{parameter}')
#
# File e:\OneDrive\Study\CS Master\Natural Language Processing\Project\nlpprojectvenv\Lib\site-packages\pandas\core\frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111 if self.columns.nlevels > 1:
#    4112     return self._getitem_multilevel(key)
# -> 4113 indexer = self.columns.get_loc(key)
#    4114 if is_integer(indexer):
#    4115     indexer = [indexer]
#
# File e:\OneDrive\Study\CS Master\Natural Language Processing\Project\nlpprojectvenv\Lib\site-packages\pandas\core\indexes\base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'time'
